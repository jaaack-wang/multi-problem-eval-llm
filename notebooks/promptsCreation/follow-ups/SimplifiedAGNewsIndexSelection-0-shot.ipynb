# %%
import os
import pandas as pd

os.chdir("../../../")
from scripts.llm import get_completion
from scripts.utils import read_obj_from_pickle
from scripts.data import make_prompts_for_clf

pd.set_option("display.max_colwidth", 150)

# %%
# simplifiy the index selection tasks by simply replacing each text with its gold label
clf_task = "AGNews"
database = read_obj_from_pickle(f"data/databases/text classification/{clf_task}.pkl")
database["testData"]["texts"] = database["testData"]["labels"]
database["devData"]["texts"] = database["devData"]["labels"]

database["promptTemplates"] = dict()
database["promptTemplates"]["0-shot"] = dict()
# Out:
# Read object from data/databases/text classification/AGNews.pkl

# %%
SelectOne = "In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n" \
            "Go over the $num lines of text below and list the index numbers of the lines that contains the word '$category' according to the following instructions:\n" \
            "If none of the texts contain the word '$category', write 'None.'\n" \
            "If all the texts contain the word '$category', write 'All.'\n" \
            "Otherwise, provide the index numbers of the texts that contain the word '$category'.\n\n" \
            "Output your responses in JSON format with the key '$category'.\nA formatted example output is provided below.\n" \
            "{'$category': [None/All or index numbers of the texts containing '$category']}\n\n" \
            "Texts, one per line:\n\n$texts\n\n" \
            "JSON output:\n"

SelectAll = "In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n" \
            "Go over the $num lines of text below and list the index numbers of the lines that contains each word according to the following instructions:\n" \
            "If none of the texts contain a particular word, write 'None.'\n" \
            "If all the texts contain a particular word, write 'All.'\n" \
            "Otherwise, provide the index numbers of the texts that contain each word.\n" \
            "Output your responses in JSON format with the following keys: 'business,' 'sports,' 'world,' and 'sci/tech.'\n" \
            "A formatted example output is provided below.\n" \
            "{'business': [None/All or index numbers of texts containing 'Business'], 'sports': [None/All or index numbers of texts containing 'Sports'], " \
            "'world': [None/All or index numbers of texts containing 'World'], 'sci/tech': [None/All or index numbers of texts containing 'Sci/Tech']}\n\n" \
            "Texts, one per line:\n\n$texts\n\n" \
            "JSON output:\n" 

tasks = ["SelectOne", "SelectAll"]
promptTemplates = [SelectOne, SelectAll]

for task, tmp in zip(tasks, promptTemplates):
    database["promptTemplates"]["0-shot"][task] = tmp

# %% [markdown]
# #### Test Prompts
#
# - The main purpose is to check if LLMs can output the desired formats given the prompts

# %%
dev = []
num_instance = 2

taskSizes = [5, 10]
for propmtMode in ["0-shot"]:
    for task in tasks:
        if task == "SingleClf":
            dev.append(make_prompts_for_clf(database, task, "dev", propmtMode)[:num_instance])
            continue

        for taskSize in taskSizes:  
            dev.append(make_prompts_for_clf(database, task, "dev", propmtMode, taskSize, attr="category", 
                                            label_attr_converter=lambda t: t, num_instance=num_instance))

dev = pd.concat(dev).reset_index(drop=True)

# %%
for p in dev[(dev["taskSize"] <= 5) & (dev["taskIndex"] == 1)].prompt:
    print(p)
    print("-"*50)
    print()
# Out:
# In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'
#
# Go over the 5 lines of text below and list the index numbers of the lines that contains the word 'Business' according to the following instructions:
# If none of the texts contain the word 'Business', write 'None.'
# If all the texts contain the word 'Business', write 'All.'
# Otherwise, provide the index numbers of the texts that contain the word 'Business'.
#
# Output your responses in JSON format with the key 'Business'.
# A formatted example output is provided below.
# {'Business': [None/All or index numbers of the texts containing 'Business']}
#
# Texts, one per line:
#
# 1. World
# 2. Sci/Tech
# 3. Sci/Tech
# 4. Sports
# 5. World
#
# JSON output:
#
# --------------------------------------------------
#
# In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'
#
# Go over the 5 lines of text below and list the index numbers of the lines that contains the word 'Sci/Tech' according to the following instructions:
# If none of the texts contain the word 'Sci/Tech', write 'None.'
# If all the texts contain the word 'Sci/Tech', write 'All.'
# Otherwise, provide the index numbers of the texts that contain the word 'Sci/Tech'.
#
# Output your responses in JSON format with the key 'Sci/Tech'.
# A formatted example output is provided below.
# {'Sci/Tech': [None/All or index numbers of the texts containing 'Sci/Tech']}
#
# Texts, one per line:
#
# 1. World
# 2. Sci/Tech
# 3. Sci/Tech
# 4. Sports
# 5. World
#
# JSON output:
#
# --------------------------------------------------
#
# In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'
#
# Go over the 5 lines of text below and list the index numbers of the lines that contains the word 'Sports' according to the following instructions:
# If none of the texts contain the word 'Sports', write 'None.'
# If all the texts contain the word 'Sports', write 'All.'
# Otherwise, provide the index numbers of the texts that contain the word 'Sports'.
#
# Output your responses in JSON format with the key 'Sports'.
# A formatted example output is provided below.
# {'Sports': [None/All or index numbers of the texts containing 'Sports']}
#
# Texts, one per line:
#
# 1. World
# 2. Sci/Tech
# 3. Sci/Tech
# 4. Sports
# 5. World
#
# JSON output:
#
# --------------------------------------------------
#
# In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'
#
# Go over the 5 lines of text below and list the index numbers of the lines that contains the word 'World' according to the following instructions:
# If none of the texts contain the word 'World', write 'None.'
# If all the texts contain the word 'World', write 'All.'
# Otherwise, provide the index numbers of the texts that contain the word 'World'.
#
# Output your responses in JSON format with the key 'World'.
# A formatted example output is provided below.
# {'World': [None/All or index numbers of the texts containing 'World']}
#
# Texts, one per line:
#
# 1. World
# 2. Sci/Tech
# 3. Sci/Tech
# 4. Sports
# 5. World
#
# JSON output:
#
# --------------------------------------------------
#
# In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'
#
# Go over the 5 lines of text below and list the index numbers of the lines that contains each word according to the following instructions:
# If none of the texts contain a particular word, write 'None.'
# If all the texts contain a particular word, write 'All.'
# Otherwise, provide the index numbers of the texts that contain each word.
# Output your responses in JSON format with the following keys: 'business,' 'sports,' 'world,' and 'sci/tech.'
# A formatted example output is provided below.
# {'business': [None/All or index numbers of texts containing 'Business'], 'sports': [None/All or index numbers of texts containing 'Sports'], 'world': [None/All or index numbers of texts containing 'World'], 'sci/tech': [None/All or index numbers of texts containing 'Sci/Tech']}
#
# Texts, one per line:
#
# 1. World
# 2. Sci/Tech
# 3. Sci/Tech
# 4. Sports
# 5. World
#
# JSON output:
#
# --------------------------------------------------

# %%
dev["preds"] = dev.prompt.apply(get_completion)
dev
# Out:
#     taskIndex  \
# 0           1
# 1           1
# 2           1
# 3           1
# 4           2
# 5           2
# 6           2
# 7           2
# 8           1
# 9           1
# 10          1
# 11          1
# 12          2
# 13          2
# 14          2
# 15          2
# 16          1
# 17          2
# 18          1
# 19          2
#
#                                                                                                                                                    prompt  \
# 0   In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 1   In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 2   In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 3   In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 4   In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 5   In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 6   In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 7   In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 8   In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 10 lines of text below an...
# 9   In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 10 lines of text below an...
# 10  In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 10 lines of text below an...
# 11  In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 10 lines of text below an...
# 12  In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 10 lines of text below an...
# 13  In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 10 lines of text below an...
# 14  In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 10 lines of text below an...
# 15  In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 10 lines of text below an...
# 16  In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 17  In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 18  In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 10 lines of text below an...
# 19  In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 10 lines of text below an...
#
#                                                                                         answer  \
# 0                                                                                       {None}
# 1                                                                                       {2, 3}
# 2                                                                                          {4}
# 3                                                                                       {1, 5}
# 4                                                                                    {3, 4, 5}
# 5                                                                                          {1}
# 6                                                                                       {None}
# 7                                                                                          {2}
# 8                                                                                       {None}
# 9                                                                                 {2, 3, 6, 7}
# 10                                                                                     {10, 4}
# 11                                                                                {8, 1, 5, 9}
# 12                                                                               {10, 3, 4, 5}
# 13                                                                                   {8, 1, 7}
# 14                                                                                      {None}
# 15                                                                                   {9, 2, 6}
# 16                  {'business': {'None'}, 'sci/tech': {2, 3}, 'sports': {4}, 'world': {1, 5}}
# 17                  {'business': {3, 4, 5}, 'sci/tech': {1}, 'sports': {'None'}, 'world': {2}}
# 18  {'business': {'None'}, 'sci/tech': {2, 3, 6, 7}, 'sports': {10, 4}, 'world': {8, 1, 5, 9}}
# 19  {'business': {10, 3, 4, 5}, 'sci/tech': {8, 1, 7}, 'sports': {'None'}, 'world': {9, 2, 6}}
#
#    targetLabel       task  #shot    CoT  taskSize  \
# 0     Business  SelectOne      0  False         5
# 1     Sci/Tech  SelectOne      0  False         5
# 2       Sports  SelectOne      0  False         5
# 3        World  SelectOne      0  False         5
# 4     Business  SelectOne      0  False         5
# 5     Sci/Tech  SelectOne      0  False         5
# 6       Sports  SelectOne      0  False         5
# 7        World  SelectOne      0  False         5
# 8     Business  SelectOne      0  False        10
# 9     Sci/Tech  SelectOne      0  False        10
# 10      Sports  SelectOne      0  False        10
# 11       World  SelectOne      0  False        10
# 12    Business  SelectOne      0  False        10
# 13    Sci/Tech  SelectOne      0  False        10
# 14      Sports  SelectOne      0  False        10
# 15       World  SelectOne      0  False        10
# 16          NA  SelectAll      0  False         5
# 17          NA  SelectAll      0  False         5
# 18          NA  SelectAll      0  False        10
# 19          NA  SelectAll      0  False        10
#
#                                                                                                               preds
# 0                                                                                      {\n    "Business": "None"\n}
# 1                                                                                      {\n    "Sci/Tech": [2, 3]\n}
# 2                                                                                                   {'Sports': [4]}
# 3                                                                                                 {'World': [1, 5]}
# 4                                                                                     {\n  "Business": [3, 4, 5]\n}
# 5                                                                                         {\n    "Sci/Tech": [1]\n}
# 6                                                                                                  {'Sports': None}
# 7                                                                                                    {'World': [2]}
# 8                                                                                                {'Business': None}
# 9                                                                                {\n    "Sci/Tech": [2, 3, 6, 7]\n}
# 10                                                                                              {'Sports': [4, 10]}
# 11                                                                                  {\n    "World": [1, 5, 8, 9]\n}
# 12                                                                                      {'Business': [3, 4, 5, 10]}
# 13                                                                                  {\n    "Sci/Tech": [1, 7, 8]\n}
# 14                                                                                                 {'Sports': None}
# 15                                                                                     {\n    "World": [2, 6, 9]\n}
# 16                  {\n    "business": "None",\n    "sports": [4],\n    "world": [1, 5],\n    "sci/tech": [2, 3]\n}
# 17                  {\n    "business": [3, 4, 5],\n    "sports": [None],\n    "world": [2],\n    "sci/tech": [1]\n}
# 18  {\n    "business": "None",\n    "sports": [4, 10],\n    "world": [1, 5, 8, 9],\n    "sci/tech": [2, 3, 6, 7]\n}
# 19  {\n    "business": [3, 4, 5, 10],\n    "sports": "None",\n    "world": [2, 6, 9],\n    "sci/tech": [1, 7, 8]\n}

# %% [markdown]
# ### Make prompts

# %%
out = []
num_instance = 100

taskSizes = [5, 10, 20, 50, 100]
for propmtMode in ["0-shot"]:
    for task in tasks:

        if task == "SingleClf":
            out.append(make_prompts_for_clf(database, task, "test", propmtMode))
            continue

        for taskSize in taskSizes:
            out.append(make_prompts_for_clf(database, task, "test", propmtMode, taskSize, attr="category", 
                                            label_attr_converter=lambda t: t, num_instance=num_instance))

out = pd.concat(out)
out.reset_index(drop=True, inplace=True)
os.makedirs("results/text classification/", exist_ok=True)
out.to_json(f"results/text classification/{clf_task}-simplified_index_selection_only.json", orient="records", lines=True)

# %%
out.task.value_counts()
# Out:
# SelectOne    2000
# SelectAll     500
# Name: task, dtype: int64

# %%
out.copy()[(out.taskIndex == 1) & (out.taskSize <= 5)]
# Out:
#       taskIndex  \
# 0             1
# 1             1
# 2             1
# 3             1
# 2000          1
#
#                                                                                                                                                      prompt  \
# 0     In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 1     In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 2     In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 3     In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
# 2000  In this task, each line of text contains one of four words 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\nGo over the 5 lines of text below and...
#
#                                                                           answer  \
# 0                                                                            {3}
# 1                                                                         {None}
# 2                                                                      {2, 4, 5}
# 3                                                                            {1}
# 2000  {'business': {3}, 'sci/tech': {'None'}, 'sports': {2, 4, 5}, 'world': {1}}
#
#      targetLabel       task  #shot    CoT  taskSize
# 0       Business  SelectOne      0  False         5
# 1       Sci/Tech  SelectOne      0  False         5
# 2         Sports  SelectOne      0  False         5
# 3          World  SelectOne      0  False         5
# 2000          NA  SelectAll      0  False         5
