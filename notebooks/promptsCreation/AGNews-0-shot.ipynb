# %%
import os
import pandas as pd

os.chdir("../../")
from scripts.llm import get_num_of_tokens, get_completion
from scripts.utils import save_obj_as_pickle, read_obj_from_pickle
from scripts.data import make_database, make_prompts_for_clf

pd.set_option("display.max_colwidth", 150)

# %%
def loadData(fp, sample_size=1000):
    df = pd.read_csv(fp)
    df.rename(columns={"Class Index": "label", "Description": "text"}, inplace=True)
    df.label = df.label.map({1: "World", 2: "Sports", 3: "Business", 4: "Sci/Tech"})
    # we only select short texts to avoid going beyond some LLM's token limit when constructing 100-problem prompts
    df = df[df.text.apply(get_num_of_tokens) <= 40].sample(sample_size, random_state=234)
    df = df[["text", "label"]].reset_index(drop=True)
    return df

clf_task = "AGNews"
test_fp = f"data/raw/text classification/{clf_task}/test.csv"
test_df = loadData(test_fp)

dev_fp = f"data/raw/text classification/{clf_task}/train.csv"
dev_df = loadData(dev_fp)

test_df.head()
# Out:
#                                                                                                                                                     text  \
# 0                                      The New York Jets and quarterback Chad Pennington are looking to finalize a contract extension by next Wednesday.
# 1  TEHRAN: Iran added one more missile to its military arsenal and the defense minister said Saturday his country was ready to confront any external ...
# 2  AFP - The second major airlift of Vietnamese Montagnards who fled to Cambodia's remote jungles after April anti-government protests will begin at ...
# 3                                                           Out of money, out of patience, out of time, and for the foreseeable future, out of business.
# 4  NEW YORK, September 3 (New Ratings) - The European Union has reportedly made significant progress in settling its prolonged antitrust case against...
#
#       label
# 0    Sports
# 1     World
# 2     World
# 3    Sports
# 4  Business

# %% [markdown]
# ### Database
#
# Sources for the prompt data

# %%
# num_instance: Number of instances to compose multi-problem prompts. Each instance contains multiple problems
# max_instance_size: Maximum number of problems sampled from the benchmark dataset to compose an instance 
# dev_df can be used for purposes such as testing the prompts or for generating exemplars 
database = make_database(test_df, dev_df, num_instance=100, max_instance_size=100)
database.keys()
# Out:
# dict_keys(['num_instance', 'max_instance_size', 'labels', 'testData', 'testInstances', 'devData', 'devInstances'])

# %% [markdown]
# #### 0-shot

# %%
database["promptTemplates"] = dict()
database["promptTemplates"]["0-shot"] = dict()

SingleClf = "Classify which news category the following line of text belongs to among the following four categories: " \
            "'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n" \
            "Text: $text\nNews category:"

BatchClf = "Classify which news category each of the $num following lines of text belongs to " \
           "among the following four categories: 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n" \
           "Texts, one per line:\n\n$texts\n\n" \
           "News categories for each of the $num lines of text, one per line:\n"

SelectOne = "This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n" \
            "Go over the $num lines of text below and list the index numbers of the lines that can be classified as $category according to the following instructions:\n" \
            "If none of the texts can be classified as $category, write 'None.'\n" \
            "If all the texts can be classified as $category, write 'All.'\n" \
            "Otherwise, provide the index numbers of the texts that can be classified as $category.\n\n" \
            "Output your responses in JSON format with the key '$category'.\nA formatted example output is provided below.\n" \
            "{'$category': [None/All or index numbers of the texts that can be classified as $category]}\n\n" \
            "Texts, one per line:\n\n$texts\n\n" \
            "JSON output:\n"

SelectAll = "This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n" \
            "Go over the $num lines of text below and list the index numbers of the lines that belong to each category according to the following instructions:\n" \
            "If none of the texts can be classified as a particular category, write 'None.'\n" \
            "If all the texts can be classified as a particular category, write 'All.'\n" \
            "Otherwise, provide the index numbers of the texts that can be classified as the category.\n" \
            "Output your responses in JSON format with the following keys: 'business,' 'sports,' 'world,' and 'sci/tech.'\n" \
            "A formatted example output is provided below.\n" \
            "{'business': [None/All or index numbers of texts in 'business' category], 'sports': [None/All or index numbers of texts in 'sports' category], " \
            "'world': [None/All or index numbers of texts in 'world' category], 'sci/tech': [None/All or index numbers of texts in sci/tech category]}\n\n" \
            "Texts, one per line:\n\n$texts\n\n" \
            "JSON output:\n" 

tasks = ["SingleClf", "BatchClf", "SelectOne", "SelectAll"]
promptTemplates = [SingleClf, BatchClf, SelectOne, SelectAll]

for task, tmp in zip(tasks, promptTemplates):
    database["promptTemplates"]["0-shot"][task] = tmp

# %%
os.makedirs("data/databases/text classification/", exist_ok=True)
save_obj_as_pickle(database, f"data/databases/text classification/{clf_task}.pkl")
# Out:
# Saved object to data/databases/text classification/AGNews.pkl

# %% [markdown]
# #### Test Prompts
#
# - The main purpose is to check if LLMs can output the desired formats given the prompts

# %%
dev = []
num_instance = 2

taskSizes = [5, 10]
for propmtMode in ["0-shot"]:
    for task in tasks:
        if task == "SingleClf":
            dev.append(make_prompts_for_clf(database, task, "dev", propmtMode)[:num_instance])
            continue

        for taskSize in taskSizes:  
            dev.append(make_prompts_for_clf(database, task, "dev", propmtMode, taskSize, attr="category", 
                                            label_attr_converter=None, num_instance=num_instance))

dev = pd.concat(dev).reset_index(drop=True)

# %%
for p in dev[(dev["taskSize"] <= 5) & (dev["taskIndex"] == 1)].prompt:
    print(p)
    print("-"*50)
    print()
# Out:
# Classify which news category the following line of text belongs to among the following four categories: 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'
#
# Text: The last time they saw each other, John Kerry was sitting in the Red Sox owner #39;s box on the eve of the Democratic National Convention and the front
# News category:
# --------------------------------------------------
#
# Classify which news category each of the 5 following lines of text belongs to among the following four categories: 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'
#
# Texts, one per line:
#
# 1. PAUL Bigley, brother of the Iraqi hostage Ken, last night appealed to Tony Blair to  quot;pick up the bloody phone quot; to save his brother #39;s life.
# 2.  quot;The PIC is being sold to consumers through service providers, like VSNL, which is a different approach for computing devices, quot; said Shane Rau of IDC.
# 3. Global IT services powerhouse EDS extended it contract with Opsware (Quote, Chart) for data center automation software and services, the company said Tuesday.
# 4. ARSENE WENGER last night taunted Real Madrid by insisting he would take over at the Bernabeu only if he was homeless and unemployed.
# 5. The governor of Baghdad escapes unhurt when a roadside bomb explodes near his convoy.
#
# News categories for each of the 5 lines of text, one per line:
#
# --------------------------------------------------
#
# This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'
#
# Go over the 5 lines of text below and list the index numbers of the lines that can be classified as business according to the following instructions:
# If none of the texts can be classified as business, write 'None.'
# If all the texts can be classified as business, write 'All.'
# Otherwise, provide the index numbers of the texts that can be classified as business.
#
# Output your responses in JSON format with the key 'business'.
# A formatted example output is provided below.
# {'business': [None/All or index numbers of the texts that can be classified as business]}
#
# Texts, one per line:
#
# 1. PAUL Bigley, brother of the Iraqi hostage Ken, last night appealed to Tony Blair to  quot;pick up the bloody phone quot; to save his brother #39;s life.
# 2.  quot;The PIC is being sold to consumers through service providers, like VSNL, which is a different approach for computing devices, quot; said Shane Rau of IDC.
# 3. Global IT services powerhouse EDS extended it contract with Opsware (Quote, Chart) for data center automation software and services, the company said Tuesday.
# 4. ARSENE WENGER last night taunted Real Madrid by insisting he would take over at the Bernabeu only if he was homeless and unemployed.
# 5. The governor of Baghdad escapes unhurt when a roadside bomb explodes near his convoy.
#
# JSON output:
#
# --------------------------------------------------
#
# This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'
#
# Go over the 5 lines of text below and list the index numbers of the lines that can be classified as sci/tech according to the following instructions:
# If none of the texts can be classified as sci/tech, write 'None.'
# If all the texts can be classified as sci/tech, write 'All.'
# Otherwise, provide the index numbers of the texts that can be classified as sci/tech.
#
# Output your responses in JSON format with the key 'sci/tech'.
# A formatted example output is provided below.
# {'sci/tech': [None/All or index numbers of the texts that can be classified as sci/tech]}
#
# Texts, one per line:
#
# 1. PAUL Bigley, brother of the Iraqi hostage Ken, last night appealed to Tony Blair to  quot;pick up the bloody phone quot; to save his brother #39;s life.
# 2.  quot;The PIC is being sold to consumers through service providers, like VSNL, which is a different approach for computing devices, quot; said Shane Rau of IDC.
# 3. Global IT services powerhouse EDS extended it contract with Opsware (Quote, Chart) for data center automation software and services, the company said Tuesday.
# 4. ARSENE WENGER last night taunted Real Madrid by insisting he would take over at the Bernabeu only if he was homeless and unemployed.
# 5. The governor of Baghdad escapes unhurt when a roadside bomb explodes near his convoy.
#
# JSON output:
#
# --------------------------------------------------
#
# This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'
#
# Go over the 5 lines of text below and list the index numbers of the lines that can be classified as sports according to the following instructions:
# If none of the texts can be classified as sports, write 'None.'
# If all the texts can be classified as sports, write 'All.'
# Otherwise, provide the index numbers of the texts that can be classified as sports.
#
# Output your responses in JSON format with the key 'sports'.
# A formatted example output is provided below.
# {'sports': [None/All or index numbers of the texts that can be classified as sports]}
#
# Texts, one per line:
#
# 1. PAUL Bigley, brother of the Iraqi hostage Ken, last night appealed to Tony Blair to  quot;pick up the bloody phone quot; to save his brother #39;s life.
# 2.  quot;The PIC is being sold to consumers through service providers, like VSNL, which is a different approach for computing devices, quot; said Shane Rau of IDC.
# 3. Global IT services powerhouse EDS extended it contract with Opsware (Quote, Chart) for data center automation software and services, the company said Tuesday.
# 4. ARSENE WENGER last night taunted Real Madrid by insisting he would take over at the Bernabeu only if he was homeless and unemployed.
# 5. The governor of Baghdad escapes unhurt when a roadside bomb explodes near his convoy.
#
# JSON output:
#
# --------------------------------------------------
#
# This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'
#
# Go over the 5 lines of text below and list the index numbers of the lines that can be classified as world according to the following instructions:
# If none of the texts can be classified as world, write 'None.'
# If all the texts can be classified as world, write 'All.'
# Otherwise, provide the index numbers of the texts that can be classified as world.
#
# Output your responses in JSON format with the key 'world'.
# A formatted example output is provided below.
# {'world': [None/All or index numbers of the texts that can be classified as world]}
#
# Texts, one per line:
#
# 1. PAUL Bigley, brother of the Iraqi hostage Ken, last night appealed to Tony Blair to  quot;pick up the bloody phone quot; to save his brother #39;s life.
# 2.  quot;The PIC is being sold to consumers through service providers, like VSNL, which is a different approach for computing devices, quot; said Shane Rau of IDC.
# 3. Global IT services powerhouse EDS extended it contract with Opsware (Quote, Chart) for data center automation software and services, the company said Tuesday.
# 4. ARSENE WENGER last night taunted Real Madrid by insisting he would take over at the Bernabeu only if he was homeless and unemployed.
# 5. The governor of Baghdad escapes unhurt when a roadside bomb explodes near his convoy.
#
# JSON output:
#
# --------------------------------------------------
#
# This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'
#
# Go over the 5 lines of text below and list the index numbers of the lines that belong to each category according to the following instructions:
# If none of the texts can be classified as a particular category, write 'None.'
# If all the texts can be classified as a particular category, write 'All.'
# Otherwise, provide the index numbers of the texts that can be classified as the category.
# Output your responses in JSON format with the following keys: 'business,' 'sports,' 'world,' and 'sci/tech.'
# A formatted example output is provided below.
# {'business': [None/All or index numbers of texts in 'business' category], 'sports': [None/All or index numbers of texts in 'sports' category], 'world': [None/All or index numbers of texts in 'world' category], 'sci/tech': [None/All or index numbers of texts in sci/tech category]}
#
# Texts, one per line:
#
# 1. PAUL Bigley, brother of the Iraqi hostage Ken, last night appealed to Tony Blair to  quot;pick up the bloody phone quot; to save his brother #39;s life.
# 2.  quot;The PIC is being sold to consumers through service providers, like VSNL, which is a different approach for computing devices, quot; said Shane Rau of IDC.
# 3. Global IT services powerhouse EDS extended it contract with Opsware (Quote, Chart) for data center automation software and services, the company said Tuesday.
# 4. ARSENE WENGER last night taunted Real Madrid by insisting he would take over at the Bernabeu only if he was homeless and unemployed.
# 5. The governor of Baghdad escapes unhurt when a roadside bomb explodes near his convoy.
#
# JSON output:
#
# --------------------------------------------------

# %%
dev["preds"] = dev.prompt.apply(get_completion)
dev
# Out:
#     taskIndex  \
# 0           1
# 1           2
# 2           1
# 3           2
# 4           1
# 5           2
# 6           1
# 7           1
# 8           1
# 9           1
# 10          2
# 11          2
# 12          2
# 13          2
# 14          1
# 15          1
# 16          1
# 17          1
# 18          2
# 19          2
# 20          2
# 21          2
# 22          1
# 23          2
# 24          1
# 25          2
#
#                                                                                                                                                    prompt  \
# 0   Classify which news category the following line of text belongs to among the following four categories: 'Business,' 'Sports,' 'World,' and 'Sci/Te...
# 1   Classify which news category the following line of text belongs to among the following four categories: 'Business,' 'Sports,' 'World,' and 'Sci/Te...
# 2   Classify which news category each of the 5 following lines of text belongs to among the following four categories: 'Business,' 'Sports,' 'World,' ...
# 3   Classify which news category each of the 5 following lines of text belongs to among the following four categories: 'Business,' 'Sports,' 'World,' ...
# 4   Classify which news category each of the 10 following lines of text belongs to among the following four categories: 'Business,' 'Sports,' 'World,'...
# 5   Classify which news category each of the 10 following lines of text belongs to among the following four categories: 'Business,' 'Sports,' 'World,'...
# 6   This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 7   This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 8   This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 9   This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 10  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 11  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 12  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 13  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 14  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 15  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 16  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 17  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 18  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 19  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 20  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 21  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 22  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 23  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 24  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 25  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
#
#                                                                                          answer  \
# 0                                                                                        Sports
# 1                                                                                        Sports
# 2                                                    [World, Sci/Tech, Sci/Tech, Sports, World]
# 3                                               [Sci/Tech, World, Business, Business, Business]
# 4          [World, Sci/Tech, Sci/Tech, Sports, World, Sci/Tech, Sci/Tech, World, World, Sports]
# 5   [Sci/Tech, World, Business, Business, Business, World, Sci/Tech, Sci/Tech, World, Business]
# 6                                                                                        {None}
# 7                                                                                        {2, 3}
# 8                                                                                           {4}
# 9                                                                                        {1, 5}
# 10                                                                                    {3, 4, 5}
# 11                                                                                          {1}
# 12                                                                                       {None}
# 13                                                                                          {2}
# 14                                                                                       {None}
# 15                                                                                 {2, 3, 6, 7}
# 16                                                                                      {10, 4}
# 17                                                                                 {8, 1, 5, 9}
# 18                                                                                {10, 3, 4, 5}
# 19                                                                                    {8, 1, 7}
# 20                                                                                       {None}
# 21                                                                                    {9, 2, 6}
# 22                   {'business': {'None'}, 'sci/tech': {2, 3}, 'sports': {4}, 'world': {1, 5}}
# 23                   {'business': {3, 4, 5}, 'sci/tech': {1}, 'sports': {'None'}, 'world': {2}}
# 24   {'business': {'None'}, 'sci/tech': {2, 3, 6, 7}, 'sports': {10, 4}, 'world': {8, 1, 5, 9}}
# 25   {'business': {10, 3, 4, 5}, 'sci/tech': {8, 1, 7}, 'sports': {'None'}, 'world': {9, 2, 6}}
#
#    targetLabel       task  #shot    CoT  taskSize  \
# 0           NA  SingleClf      0  False         1
# 1           NA  SingleClf      0  False         1
# 2           NA   BatchClf      0  False         5
# 3           NA   BatchClf      0  False         5
# 4           NA   BatchClf      0  False        10
# 5           NA   BatchClf      0  False        10
# 6     Business  SelectOne      0  False         5
# 7     Sci/Tech  SelectOne      0  False         5
# 8       Sports  SelectOne      0  False         5
# 9        World  SelectOne      0  False         5
# 10    Business  SelectOne      0  False         5
# 11    Sci/Tech  SelectOne      0  False         5
# 12      Sports  SelectOne      0  False         5
# 13       World  SelectOne      0  False         5
# 14    Business  SelectOne      0  False        10
# 15    Sci/Tech  SelectOne      0  False        10
# 16      Sports  SelectOne      0  False        10
# 17       World  SelectOne      0  False        10
# 18    Business  SelectOne      0  False        10
# 19    Sci/Tech  SelectOne      0  False        10
# 20      Sports  SelectOne      0  False        10
# 21       World  SelectOne      0  False        10
# 22          NA  SelectAll      0  False         5
# 23          NA  SelectAll      0  False         5
# 24          NA  SelectAll      0  False        10
# 25          NA  SelectAll      0  False        10
#
#                                                                                                                     preds
# 0                                                                                                                  Sports
# 1                                                                                                                  Sports
# 2                                                                 1. World\n2. Sci/Tech\n3. Business\n4. Sports\n5. World
# 3                                                               1. World\n2. World\n3. Business\n4. Business\n5. Business
# 4          1. World\n2. Sci/Tech\n3. Business\n4. Sports\n5. World\n6. World\n7. Sci/Tech\n8. World\n9. World\n10. Sports
# 5   1. World\n2. World\n3. Business\n4. Business\n5. Business\n6. World\n7. Sci/Tech\n8. Sci/Tech\n9. World\n10. Business
# 6                                                                                                    {'business': [2, 3]}
# 7                                                                                                    {'sci/tech': [2, 3]}
# 8                                                                                                      {'sports': [None]}
# 9                                                                                                  {\n    "world": [5]\n}
# 10                                                                                                      {'business': [3]}
# 11                                                                                                   {'sci/tech': [None]}
# 12                                                                                                     {'sports': [None]}
# 13                                                                                                      {'world': [None]}
# 14                                                                                                {'business': [2, 3, 7]}
# 15                                                                                     {\n    "sci/tech": [2, 3, 7, 8]\n}
# 16                                                                                                       {'sports': [10]}
# 17                                                                                                      {'world': [5, 9]}
# 18                                                                                               {'business': [3, 4, 10]}
# 19                                                                                                      {'sci/tech': [7]}
# 20                                                                                                       {'sports': None}
# 21                                                                                              {\n    "world": [None]\n}
# 22                        {\n    "business": [2, 3],\n    "sports": [4],\n    "world": [1, 5],\n    "sci/tech": [None]\n}
# 23               {\n    "business": [2, 3],\n    "sports": [None],\n    "world": [1, 2, 4, 5],\n    "sci/tech": [None]\n}
# 24        {\n    "business": [2, 3, 7, 8],\n    "sports": [4, 10],\n    "world": [1, 5, 6, 9],\n    "sci/tech": [None]\n}
# 25                 {\n    "business": [3, 4, 10],\n    "sports": [None],\n    "world": [2, 9],\n    "sci/tech": [7, 8]\n}

# %% [markdown]
# ### Make prompts

# %%
database = read_obj_from_pickle(f"data/databases/text classification/{clf_task}.pkl")
# Out:
# Read object from data/databases/text classification/AGNews.pkl

# %%
out = []
num_instance = 100

taskSizes = [5, 10, 20, 50, 100]
for propmtMode in ["0-shot"]:
    for task in tasks:

        if task == "SingleClf":
            out.append(make_prompts_for_clf(database, task, "test", propmtMode))
            continue

        for taskSize in taskSizes:
            out.append(make_prompts_for_clf(database, task, "test", propmtMode, taskSize, attr="category", 
                                            label_attr_converter=None, num_instance=num_instance))

out = pd.concat(out)
out.reset_index(drop=True, inplace=True)

os.makedirs("results/text classification/", exist_ok=True)
out.to_json(f"results/text classification/{clf_task}.json", orient="records", lines=True)

# %%
out.task.value_counts()
# Out:
# SelectOne    2000
# SingleClf    1000
# BatchClf      500
# SelectAll     500
# Name: task, dtype: int64

# %%
out.copy()[(out.taskIndex == 1) & (out.taskSize <= 5)]
# Out:
#       taskIndex  \
# 0             1
# 1000          1
# 1500          1
# 1501          1
# 1502          1
# 1503          1
# 3500          1
#
#                                                                                                                                                      prompt  \
# 0     Classify which news category the following line of text belongs to among the following four categories: 'Business,' 'Sports,' 'World,' and 'Sci/Te...
# 1000  Classify which news category each of the 5 following lines of text belongs to among the following four categories: 'Business,' 'Sports,' 'World,' ...
# 1500  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 1501  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 1502  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 1503  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
# 3500  This is a news classification task in which each line of text belongs to one of four categories 'Business,' 'Sports,' 'World,' and 'Sci/Tech.'\n\n...
#
#                                                                           answer  \
# 0                                                                         Sports
# 1000                                   [World, Sports, Business, Sports, Sports]
# 1500                                                                         {3}
# 1501                                                                      {None}
# 1502                                                                   {2, 4, 5}
# 1503                                                                         {1}
# 3500  {'business': {3}, 'sci/tech': {'None'}, 'sports': {2, 4, 5}, 'world': {1}}
#
#      targetLabel       task  #shot    CoT  taskSize
# 0             NA  SingleClf      0  False         1
# 1000          NA   BatchClf      0  False         5
# 1500    Business  SelectOne      0  False         5
# 1501    Sci/Tech  SelectOne      0  False         5
# 1502      Sports  SelectOne      0  False         5
# 1503       World  SelectOne      0  False         5
# 3500          NA  SelectAll      0  False         5
