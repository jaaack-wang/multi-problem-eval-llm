# %%
import os
import pandas as pd

os.chdir("../../")
from scripts.llm import get_num_of_tokens, get_completion
from scripts.utils import save_obj_as_pickle, read_obj_from_pickle
from scripts.data import make_database, make_prompts_for_clf

pd.set_option("display.max_colwidth", 150)

# %%
def loadData(fp):
    data = []
    for line in open(fp).readlines()[1:]:
        data.append([s.strip() for s in line.split("\t")])

    df = pd.DataFrame(data, columns=["label", "id1", "id2", "text1", "text2"])
    df = df[["label", "text1", "text2"]]
    df.label = df.label.map({"0": "No", "1": "Yes"})
    df["text"] = "Text A: " + df.text1 + "\nText B: " + df.text2 + "\n"
    df = df[['label', 'text']]

    return df

clf_task = "MRPC"
test_fp = f"data/raw/text classification/{clf_task}/test.tsv"
test_df = loadData(test_fp)

dev_fp = f"data/raw/text classification/{clf_task}/val.tsv"
dev_df = loadData(dev_fp)

test_df.head()
# Out:
#   label  \
# 0   Yes
# 1   Yes
# 2   Yes
# 3    No
# 4    No
#
#                                                                                                                                                     text
# 0  Text A: PCCW's chief operating officer, Mike Butcher, and Alex Arena, the chief financial officer, will report directly to Mr So.\nText B: Current...
# 1  Text A: The world's two largest automakers said their U.S. sales declined more than predicted last month as a late summer sales frenzy caused more...
# 2  Text A: According to the federal Centers for Disease Control and Prevention (news - web sites), there were 19 reported cases of measles in the Uni...
# 3  Text A: A tropical storm rapidly developed in the Gulf of Mexico Sunday and was expected to hit somewhere along the Texas or Louisiana coasts by M...
# 4  Text A: The company didn't detail the costs of the replacement and repairs.\nText B: But company officials expect the costs of the replacement wor...

# %%
test_df.label.value_counts()
# Out:
# Yes    1147
# No      578
# Name: label, dtype: int64

# %%
(test_df.label.value_counts() / len(test_df)).round(3) * 100
# Out:
# Yes    66.5
# No     33.5
# Name: label, dtype: float64

# %%
test_df.text.apply(get_num_of_tokens).describe()
# Out:
# count    1725.000000
# mean       55.552464
# std        13.058420
# min        21.000000
# 25%        46.000000
# 50%        55.000000
# 75%        65.000000
# max       108.000000
# Name: text, dtype: float64

# %%
dev_df.label.value_counts()
# Out:
# Yes    346
# No     154
# Name: label, dtype: int64

# %%
dev_df.text.apply(get_num_of_tokens).describe()
# Out:
# count    500.000000
# mean      55.472000
# std       12.616003
# min       24.000000
# 25%       47.000000
# 50%       55.000000
# 75%       64.000000
# max       92.000000
# Name: text, dtype: float64

# %% [markdown]
# ### Database
#
# Sources for the prompt data

# %%
database = make_database(test_df, dev_df, num_instance=500, max_instance_size=500)
database.keys()
# Out:
# dict_keys(['num_instance', 'max_instance_size', 'labels', 'testData', 'testInstances', 'devData', 'devInstances'])

# %% [markdown]
# #### Zero-shot

# %%
database["promptTemplates"] = dict()
database["promptTemplates"]["zero-shot"] = dict()


single_clf = "Compare text A with text B and determine if text A is a paraphrase of text B. " \
             "Respond with 'Yes' if text A is a paraphrase, and 'No' if it is not.\n\n" \
             "$text\nAnswer:"

batch_clf = "Compare text A with text B for the following $num text pairs and determine if text A is a paraphrase of text B line by line. " \
            "Respond with 'Yes' if text A is a paraphrase, and 'No' if it is not. Provide your answers line by line.\n\n" \
            "$texts\nAnswers:\n" 

index_selection_one_cat_a_time = "Go over the $num text pairs below and list the index numbers of the text pairs where text A $be a paraphrase of text B according to the following instructions:\n" \
                                 "If none of the text pairs satisfy this condition, write 'None.'\n" \
                                 "If all the text pairs satisfy this condition, write 'All.'\n" \
                                 "Otherwise, provide the index numbers of the text pairs where text A $be a paraphrase of text B, each on a separate line.\n\n" \
                                 "Here are the text pairs:\n\n$texts\n" \
                                 "'None,' 'All,' or the index numbers of the text pairs where text A $be a paraphrase of text B:\n"

index_selection_one_cat_a_time_json =   "Go over the $num text pairs below and list the index numbers of the text pairs where text A $be a paraphrase of text B according to the following instructions:\n" \
                                        "If none of the text pairs satisfy this condition, write 'None.'\n" \
                                        "If all the text pairs satisfy this condition, write 'All.'\n" \
                                        "Otherwise, provide the index numbers of the text pairs where text A $be a paraphrase of text B.\n\n" \
                                        "Output your responses in JSON format with the key 'answer'.\nA formatted example output is provided below.\n" \
                                        "{'answer': [None/All or index numbers of the text pairs where text A $be a paraphrase of text B]}\n\n" \
                                        "Here are the text pairs:\n\n$texts\n" \
                                        "JSON output:\n"

index_selection_all_cat_at_once = "Go over the $num text pairs below. First, list the index numbers of the text pairs that contain paraphrases. " \
                                  "Then, list the index numbers of the text pairs that contain non-paraphrases.\n" \
                                  "If none of the text pairs satisfy a condition, write 'None.'\n" \
                                  "If all the text pairs satisfy a condition, write 'All.'\n" \
                                  "Otherwise, provide the index numbers of the text pairs that satisfy each condition.\n\n" \
                                  "Here are the text pairs:\n\n$texts\n" \
                                  "Output your responses in JSON format with two keys: 'yes' for paraphrases and 'no' for non-paraphrases." \
                                  "\nA formatted example output is provided below.\n" \
                                  "{'yes': [None/All or index numbers of text pairs that contain paraphrases], " \
                                  "'no': [None/All or index numbers of text pairs that contain non-paraphrases]}"

index_selection_all_cat_at_once_adjusted = "Go over the $num text pairs below. First, list the index numbers of the text pairs that contain paraphrases. " \
                                            "Then, list the index numbers of the text pairs that contain non-paraphrases.\n" \
                                            "If none of the text pairs satisfy a condition, write 'None.'\n" \
                                            "If all the text pairs satisfy a condition, write 'All.'\n" \
                                            "Otherwise, provide the index numbers of the text pairs that satisfy each condition.\n\n" \
                                            "Output your responses in JSON format with two keys: 'yes' for paraphrases and 'no' for non-paraphrases." \
                                            "\nA formatted example output is provided below.\n" \
                                            "{'yes': [None/All or index numbers of text pairs that contain paraphrases], " \
                                            "'no': [None/All or index numbers of text pairs that contain non-paraphrases]}\n\n" \
                                            "Here are the text pairs:\n\n$texts\n" \
                                            "JSON output:\n"

tasks = ["single_clf", "batch_clf", "index_selection_one_cat_a_time", 
         "index_selection_all_cat_at_once", "index_selection_all_cat_at_once_adjusted", "index_selection_one_cat_a_time_json"]
promptTemplates = [single_clf, batch_clf, index_selection_one_cat_a_time, 
                   index_selection_all_cat_at_once, index_selection_all_cat_at_once_adjusted, index_selection_one_cat_a_time_json]

for task, tmp in zip(tasks, promptTemplates):
    database["promptTemplates"]["zero-shot"][task] = tmp

# %%
os.makedirs("data/databases/text classification/", exist_ok=True)
save_obj_as_pickle(database, f"data/databases/text classification/{clf_task}.pkl")
# Out:
# Saved object to data/databases/text classification/MRPC.pkl

# %% [markdown]
# #### Test Prompts
#
# - The main purpose is to check if LLMs can output the desired formats given the prompts

# %%
dev = []
num_instance = 2
label_attr_converter = lambda t: {"Yes": "is", "No": "isn't"}[t]
taskSizes = [3, 5]
for propmtMode in ["zero-shot"]:
    for task in tasks:
        if task == "single_clf":
            dev.append(make_prompts_for_clf(database, task, "dev", propmtMode)[:num_instance])
            continue

        for taskSize in taskSizes:  
            dev.append(make_prompts_for_clf(database, task, "dev", propmtMode, taskSize, attr="be", 
                                            label_attr_converter=label_attr_converter, num_instance=num_instance))

dev = pd.concat(dev).reset_index(drop=True)

# %%
for p in dev[(dev["taskSize"] <= 3) & (dev["taskIndex"] == 1)].prompt:
    print(p)
    print("-"*50)
    print()
# Out:
# Compare text A with text B and determine if text A is a paraphrase of text B. Respond with 'Yes' if text A is a paraphrase, and 'No' if it is not.
#
# Text A: Stocks have rallied sharply for more than three months in anticipation of a rebound in the second half of the year.
# Text B: Stocks have rallied sharply for more than three months in anticipation of an economic rebound in the year's second half.
#
# Answer:
# --------------------------------------------------
#
# Compare text A with text B for the following 3 text pairs and determine if text A is a paraphrase of text B line by line. Respond with 'Yes' if text A is a paraphrase, and 'No' if it is not. Provide your answers line by line.
#
# 1. Text A: "I still want to be the candidate for guys with Confederate flags in their pickup trucks," Dean said Friday in a telephone interview from New Hampshire.
# Text B: "I still want to be the candidate for guys with Confederate flags in their pickup trucks," he told The Des Moines Register.
#
# 2. Text A: Lloyds TSB confirmed on Tuesday it was "considering its options" over the sale of its National Bank of New Zealand subsidiary.
# Text B: Lloyds TSB yesterday confirmed that it had received bids for its National Bank of New Zealand operation.
#
# 3. Text A: Asked about other possible attacks, Roberts said: "I don't think there's any question about it that . . . they're going to be very global in nature.
# Text B: Asked about other possible attacks, Roberts said: “I don’t think there’s any question about it that they’re going to be very global in nature.
#
# Answers:
#
# --------------------------------------------------
#
# Go over the 3 text pairs below and list the index numbers of the text pairs where text A isn't a paraphrase of text B according to the following instructions:
# If none of the text pairs satisfy this condition, write 'None.'
# If all the text pairs satisfy this condition, write 'All.'
# Otherwise, provide the index numbers of the text pairs where text A isn't a paraphrase of text B, each on a separate line.
#
# Here are the text pairs:
#
# 1. Text A: "I still want to be the candidate for guys with Confederate flags in their pickup trucks," Dean said Friday in a telephone interview from New Hampshire.
# Text B: "I still want to be the candidate for guys with Confederate flags in their pickup trucks," he told The Des Moines Register.
#
# 2. Text A: Lloyds TSB confirmed on Tuesday it was "considering its options" over the sale of its National Bank of New Zealand subsidiary.
# Text B: Lloyds TSB yesterday confirmed that it had received bids for its National Bank of New Zealand operation.
#
# 3. Text A: Asked about other possible attacks, Roberts said: "I don't think there's any question about it that . . . they're going to be very global in nature.
# Text B: Asked about other possible attacks, Roberts said: “I don’t think there’s any question about it that they’re going to be very global in nature.
#
# 'None,' 'All,' or the index numbers of the text pairs where text A isn't a paraphrase of text B:
#
# --------------------------------------------------
#
# Go over the 3 text pairs below and list the index numbers of the text pairs where text A is a paraphrase of text B according to the following instructions:
# If none of the text pairs satisfy this condition, write 'None.'
# If all the text pairs satisfy this condition, write 'All.'
# Otherwise, provide the index numbers of the text pairs where text A is a paraphrase of text B, each on a separate line.
#
# Here are the text pairs:
#
# 1. Text A: "I still want to be the candidate for guys with Confederate flags in their pickup trucks," Dean said Friday in a telephone interview from New Hampshire.
# Text B: "I still want to be the candidate for guys with Confederate flags in their pickup trucks," he told The Des Moines Register.
#
# 2. Text A: Lloyds TSB confirmed on Tuesday it was "considering its options" over the sale of its National Bank of New Zealand subsidiary.
# Text B: Lloyds TSB yesterday confirmed that it had received bids for its National Bank of New Zealand operation.
#
# 3. Text A: Asked about other possible attacks, Roberts said: "I don't think there's any question about it that . . . they're going to be very global in nature.
# Text B: Asked about other possible attacks, Roberts said: “I don’t think there’s any question about it that they’re going to be very global in nature.
#
# 'None,' 'All,' or the index numbers of the text pairs where text A is a paraphrase of text B:
#
# --------------------------------------------------
#
# Go over the 3 text pairs below. First, list the index numbers of the text pairs that contain paraphrases. Then, list the index numbers of the text pairs that contain non-paraphrases.
# If none of the text pairs satisfy a condition, write 'None.'
# If all the text pairs satisfy a condition, write 'All.'
# Otherwise, provide the index numbers of the text pairs that satisfy each condition.
#
# Here are the text pairs:
#
# 1. Text A: "I still want to be the candidate for guys with Confederate flags in their pickup trucks," Dean said Friday in a telephone interview from New Hampshire.
# Text B: "I still want to be the candidate for guys with Confederate flags in their pickup trucks," he told The Des Moines Register.
#
# 2. Text A: Lloyds TSB confirmed on Tuesday it was "considering its options" over the sale of its National Bank of New Zealand subsidiary.
# Text B: Lloyds TSB yesterday confirmed that it had received bids for its National Bank of New Zealand operation.
#
# 3. Text A: Asked about other possible attacks, Roberts said: "I don't think there's any question about it that . . . they're going to be very global in nature.
# Text B: Asked about other possible attacks, Roberts said: “I don’t think there’s any question about it that they’re going to be very global in nature.
#
# Output your responses in JSON format with two keys: 'yes' for paraphrases and 'no' for non-paraphrases.
# A formatted example output is provided below.
# {'yes': [None/All or index numbers of text pairs that contain paraphrases], 'no': [None/All or index numbers of text pairs that contain non-paraphrases]}
# --------------------------------------------------

# %%
dev["preds"] = dev.prompt.apply(get_completion)
dev
# Out:
#     taskIndex  \
# 0           1
# 1           2
# 2           1
# 3           2
# 4           1
# 5           2
# 6           1
# 7           1
# 8           2
# 9           2
# 10          1
# 11          1
# 12          2
# 13          2
# 14          1
# 15          2
# 16          1
# 17          2
#
#                                                                                                                                                    prompt  \
# 0   Compare text A with text B and determine if text A is a paraphrase of text B. Respond with 'Yes' if text A is a paraphrase, and 'No' if it is not....
# 1   Compare text A with text B and determine if text A is a paraphrase of text B. Respond with 'Yes' if text A is a paraphrase, and 'No' if it is not....
# 2   Compare text A with text B for the following 3 text pairs and determine if text A is a paraphrase of text B line by line. Respond with 'Yes' if te...
# 3   Compare text A with text B for the following 3 text pairs and determine if text A is a paraphrase of text B line by line. Respond with 'Yes' if te...
# 4   Compare text A with text B for the following 5 text pairs and determine if text A is a paraphrase of text B line by line. Respond with 'Yes' if te...
# 5   Compare text A with text B for the following 5 text pairs and determine if text A is a paraphrase of text B line by line. Respond with 'Yes' if te...
# 6   Go over the 3 text pairs below and list the index numbers of the text pairs where text A isn't a paraphrase of text B according to the following i...
# 7   Go over the 3 text pairs below and list the index numbers of the text pairs where text A is a paraphrase of text B according to the following inst...
# 8   Go over the 3 text pairs below and list the index numbers of the text pairs where text A isn't a paraphrase of text B according to the following i...
# 9   Go over the 3 text pairs below and list the index numbers of the text pairs where text A is a paraphrase of text B according to the following inst...
# 10  Go over the 5 text pairs below and list the index numbers of the text pairs where text A isn't a paraphrase of text B according to the following i...
# 11  Go over the 5 text pairs below and list the index numbers of the text pairs where text A is a paraphrase of text B according to the following inst...
# 12  Go over the 5 text pairs below and list the index numbers of the text pairs where text A isn't a paraphrase of text B according to the following i...
# 13  Go over the 5 text pairs below and list the index numbers of the text pairs where text A is a paraphrase of text B according to the following inst...
# 14  Go over the 3 text pairs below. First, list the index numbers of the text pairs that contain paraphrases. Then, list the index numbers of the text...
# 15  Go over the 3 text pairs below. First, list the index numbers of the text pairs that contain paraphrases. Then, list the index numbers of the text...
# 16  Go over the 5 text pairs below. First, list the index numbers of the text pairs that contain paraphrases. Then, list the index numbers of the text...
# 17  Go over the 5 text pairs below. First, list the index numbers of the text pairs that contain paraphrases. Then, list the index numbers of the text...
#
#                               answer targetLabel  \
# 0                                Yes          NA
# 1                                 No          NA
# 2                    [Yes, Yes, Yes]          NA
# 3                    [Yes, Yes, Yes]          NA
# 4          [Yes, Yes, Yes, Yes, Yes]          NA
# 5          [Yes, Yes, Yes, Yes, Yes]          NA
# 6                             {None}          No
# 7                              {All}         Yes
# 8                             {None}          No
# 9                              {All}         Yes
# 10                            {None}          No
# 11                             {All}         Yes
# 12                            {None}          No
# 13                             {All}         Yes
# 14  {'no': {'None'}, 'yes': {'All'}}          NA
# 15  {'no': {'None'}, 'yes': {'All'}}          NA
# 16  {'no': {'None'}, 'yes': {'All'}}          NA
# 17  {'no': {'None'}, 'yes': {'All'}}          NA
#
#                                task  #shot    CoT  taskSize  \
# 0                        single_clf      0  False         1
# 1                        single_clf      0  False         1
# 2                         batch_clf      0  False         3
# 3                         batch_clf      0  False         3
# 4                         batch_clf      0  False         5
# 5                         batch_clf      0  False         5
# 6    index_selection_one_cat_a_time      0  False         3
# 7    index_selection_one_cat_a_time      0  False         3
# 8    index_selection_one_cat_a_time      0  False         3
# 9    index_selection_one_cat_a_time      0  False         3
# 10   index_selection_one_cat_a_time      0  False         5
# 11   index_selection_one_cat_a_time      0  False         5
# 12   index_selection_one_cat_a_time      0  False         5
# 13   index_selection_one_cat_a_time      0  False         5
# 14  index_selection_all_cat_at_once      0  False         3
# 15  index_selection_all_cat_at_once      0  False         3
# 16  index_selection_all_cat_at_once      0  False         5
# 17  index_selection_all_cat_at_once      0  False         5
#
#                                                                                preds
# 0                                                                                Yes
# 1                                                                                 No
# 2                                                               1. No\n2. No\n3. Yes
# 3                                                               1. No\n2. Yes\n3. No
# 4                                                1. No\n2. No\n3. Yes\n4. No\n5. Yes
# 5                                                1. No\n2. Yes\n3. No\n4. No\n5. Yes
# 6                                                                              None.
# 7                                                              1. 1\n2. None\n3. All
# 8                                                                              None.
# 9                                                                         1\n2\nNone
# 10                                                                             None.
# 11                                                                                 1
# 12                                                                             None.
# 13                                                                              1\n4
# 14                                               {\n  "yes": [1, 3],\n  "no": [2]\n}
# 15  {\n    "yes": [\n        1,\n        2\n    ],\n    "no": [\n        3\n    ]\n}
# 16      {\n  "yes": [\n    1,\n    3\n  ],\n  "no": [\n    2,\n    4,\n    5\n  ]\n}
# 17                                     {\n    "yes": [1, 2],\n    "no": [3, 4, 5]\n}

# %% [markdown]
# ### Adjusted

# %%
dev = []
num_instance = 2

taskSizes = [3, 5]
label_attr_converter = lambda t: {"Yes": "is", "No": "isn't"}[t]

for propmtMode in ["zero-shot"]:
    for task in tasks[-1:]:
        if task == "single_clf":
            dev.append(make_prompts_for_clf(database, task, "dev", propmtMode)[:num_instance])
            continue

        for taskSize in taskSizes:  
            dev.append(make_prompts_for_clf(database, task, "dev", propmtMode, taskSize, attr="be", 
                                            label_attr_converter=label_attr_converter, num_instance=num_instance))

dev = pd.concat(dev).reset_index(drop=True)

# %%
for p in dev[(dev["taskSize"] <= 3) & (dev["taskIndex"] == 1)].prompt:
    print(p)
    print("-"*50)
    print()
# Out:
# Go over the 3 text pairs below and list the index numbers of the text pairs where text A isn't a paraphrase of text B according to the following instructions:
# If none of the text pairs satisfy this condition, write 'None.'
# If all the text pairs satisfy this condition, write 'All.'
# Otherwise, provide the index numbers of the text pairs where text A isn't a paraphrase of text B.
#
# Output your responses in JSON format with the key 'answer'.
# A formatted example output is provided below.
# {'answer': [None/All or index numbers of the text pairs where text A isn't a paraphrase of text B]}
#
# Here are the text pairs:
#
# 1. Text A: "I still want to be the candidate for guys with Confederate flags in their pickup trucks," Dean said Friday in a telephone interview from New Hampshire.
# Text B: "I still want to be the candidate for guys with Confederate flags in their pickup trucks," he told The Des Moines Register.
#
# 2. Text A: Lloyds TSB confirmed on Tuesday it was "considering its options" over the sale of its National Bank of New Zealand subsidiary.
# Text B: Lloyds TSB yesterday confirmed that it had received bids for its National Bank of New Zealand operation.
#
# 3. Text A: Asked about other possible attacks, Roberts said: "I don't think there's any question about it that . . . they're going to be very global in nature.
# Text B: Asked about other possible attacks, Roberts said: “I don’t think there’s any question about it that they’re going to be very global in nature.
#
# JSON output:
#
# --------------------------------------------------
#
# Go over the 3 text pairs below and list the index numbers of the text pairs where text A is a paraphrase of text B according to the following instructions:
# If none of the text pairs satisfy this condition, write 'None.'
# If all the text pairs satisfy this condition, write 'All.'
# Otherwise, provide the index numbers of the text pairs where text A is a paraphrase of text B.
#
# Output your responses in JSON format with the key 'answer'.
# A formatted example output is provided below.
# {'answer': [None/All or index numbers of the text pairs where text A is a paraphrase of text B]}
#
# Here are the text pairs:
#
# 1. Text A: "I still want to be the candidate for guys with Confederate flags in their pickup trucks," Dean said Friday in a telephone interview from New Hampshire.
# Text B: "I still want to be the candidate for guys with Confederate flags in their pickup trucks," he told The Des Moines Register.
#
# 2. Text A: Lloyds TSB confirmed on Tuesday it was "considering its options" over the sale of its National Bank of New Zealand subsidiary.
# Text B: Lloyds TSB yesterday confirmed that it had received bids for its National Bank of New Zealand operation.
#
# 3. Text A: Asked about other possible attacks, Roberts said: "I don't think there's any question about it that . . . they're going to be very global in nature.
# Text B: Asked about other possible attacks, Roberts said: “I don’t think there’s any question about it that they’re going to be very global in nature.
#
# JSON output:
#
# --------------------------------------------------

# %%
model = "meta-llama/Llama-3-8b-chat-hf"
dev["preds"] = dev.prompt.apply(lambda p: get_completion(p, model))
dev
# Out:
#    taskIndex  \
# 0          1
# 1          1
# 2          2
# 3          2
# 4          1
# 5          1
# 6          2
# 7          2
#
#                                                                                                                                                   prompt  \
# 0  Go over the 3 text pairs below and list the index numbers of the text pairs where text A isn't a paraphrase of text B according to the following i...
# 1  Go over the 3 text pairs below and list the index numbers of the text pairs where text A is a paraphrase of text B according to the following inst...
# 2  Go over the 3 text pairs below and list the index numbers of the text pairs where text A isn't a paraphrase of text B according to the following i...
# 3  Go over the 3 text pairs below and list the index numbers of the text pairs where text A is a paraphrase of text B according to the following inst...
# 4  Go over the 5 text pairs below and list the index numbers of the text pairs where text A isn't a paraphrase of text B according to the following i...
# 5  Go over the 5 text pairs below and list the index numbers of the text pairs where text A is a paraphrase of text B according to the following inst...
# 6  Go over the 5 text pairs below and list the index numbers of the text pairs where text A isn't a paraphrase of text B according to the following i...
# 7  Go over the 5 text pairs below and list the index numbers of the text pairs where text A is a paraphrase of text B according to the following inst...
#
#    answer targetLabel                                 task  #shot    CoT  \
# 0  {None}          No  index_selection_one_cat_a_time_json      0  False
# 1   {All}         Yes  index_selection_one_cat_a_time_json      0  False
# 2  {None}          No  index_selection_one_cat_a_time_json      0  False
# 3   {All}         Yes  index_selection_one_cat_a_time_json      0  False
# 4  {None}          No  index_selection_one_cat_a_time_json      0  False
# 5   {All}         Yes  index_selection_one_cat_a_time_json      0  False
# 6  {None}          No  index_selection_one_cat_a_time_json      0  False
# 7   {All}         Yes  index_selection_one_cat_a_time_json      0  False
#
#    taskSize  \
# 0         3
# 1         3
# 2         3
# 3         3
# 4         5
# 5         5
# 6         5
# 7         5
#
#                                                                                                                                                    preds
# 0  Here is the output in JSON format:\n\n{\n"answer": [2]\n}\n\nExplanation:\n\n* Text pair 1: Text A and Text B are identical, so they are paraphras...
# 1  Here is the output in JSON format:\n\n{\n"answer": [2]\n}\n\nExplanation:\n\n* Text pair 1: Text A and Text B are identical, but the source of the...
# 2  Here is the output in JSON format:\n\n{\n"answer": [2]\n}\n\nExplanation:\n\n* Text pair 1: Text A and Text B are paraphrases of each other, as th...
# 3  Here is the output in JSON format:\n\n{\n"answer": [2]\n}\n\nExplanation:\n\n* Text pair 1: Text A is not a paraphrase of Text B, as the wording a...
# 4  Here is the output in JSON format:\n\n{\n"answer": [2, 4]\n}\n\nExplanation:\n\n* Text pair 1: Text A and Text B are paraphrases of each other.\n*...
# 5  Here is the output in JSON format:\n\n{\n"answer": [2, 4]\n}\n\nExplanation:\n\n* Text pair 2: Text A is a paraphrase of Text B, as both sentences...
# 6  Here is the output in JSON format:\n\n{\n"answer": [2, 4]\n}\n\nExplanation:\n\n* Text pair 1: Text A and Text B are paraphrases of each other.\n*...
# 7  Here is the output in JSON format:\n\n{\n"answer": [2, 4]\n}\n\nExplanation:\n\n* Text pair 2: Text A is a paraphrase of Text B, as they both desc...

# %% [markdown]
# ### Make prompts

# %%
database = read_obj_from_pickle(f"data/databases/text classification/{clf_task}.pkl")
# Out:
# Read object from data/databases/text classification/MRPC.pkl

# %%
# out = []
# num_instance = 100
# taskSizes = [3, 5, 10, 20, 50]
# for propmtMode in ["zero-shot"]:
#     for task in tasks:

#         if task == "single_clf":
#             out.append(make_prompts_for_clf(database, task, "test", propmtMode))
#             continue

#         for taskSize in taskSizes:
#             out.append(make_prompts_for_clf(database, task, "test", propmtMode, taskSize, attr="be", 
#                                             label_attr_converter=label_attr_converter, num_instance=num_instance))

# out = pd.concat(out)
# out.reset_index(drop=True, inplace=True)

# os.makedirs("results/text classification/", exist_ok=True)
# out.to_json(f"results/text classification/{clf_task}.json", orient="records", lines=True)

# %%
fp = f"results/text classification/{clf_task}.json"
out = [pd.read_json(fp, lines=True)]

num_instance = 100
taskSizes = [3, 5, 10, 20, 50]
for propmtMode in ["zero-shot"]:
    for taskSize in taskSizes:
        out.append(make_prompts_for_clf(database, tasks[-1], "test", propmtMode, taskSize, attr="be", 
                                        label_attr_converter=label_attr_converter, num_instance=num_instance))

out = pd.concat(out)
out.reset_index(drop=True, inplace=True)

os.makedirs("results/text classification/", exist_ok=True)
out.to_json(f"results/text classification/{clf_task}.json", orient="records", lines=True)

# %%
out.task.value_counts()
# Out:
# single_clf                                  1725
# index_selection_one_cat_a_time              1000
# index_selection_one_cat_a_time_json         1000
# batch_clf                                    500
# index_selection_all_cat_at_once              500
# index_selection_all_cat_at_once_adjusted     500
# Name: task, dtype: int64

# %%
out.prompt.apply(get_num_of_tokens).describe()
# Out:
# count    5225.000000
# mean      798.788900
# std       950.927107
# min        64.000000
# 25%       108.000000
# 50%       395.000000
# 75%      1207.000000
# max      3265.000000
# Name: prompt, dtype: float64

# %%
sub = out.copy()[(out.taskIndex == 1) & (out.taskSize <= 3)]
sub
# Out:
#       taskIndex  \
# 0             1
# 1725          1
# 2225          1
# 2226          1
# 3225          1
# 3725          1
# 4225          1
# 4226          1
#
#                                                                                                                                                      prompt  \
# 0     Compare text A with text B and determine if text A is a paraphrase of text B. Respond with 'Yes' if text A is a paraphrase, and 'No' if it is not....
# 1725  Compare text A with text B for the following 3 text pairs and determine if text A is a paraphrase of text B line by line. Respond with 'Yes' if te...
# 2225  Go over the 3 text pairs below and list the index numbers of the text pairs where text A isn't a paraphrase of text B according to the following i...
# 2226  Go over the 3 text pairs below and list the index numbers of the text pairs where text A is a paraphrase of text B according to the following inst...
# 3225  Go over the 3 text pairs below. First, list the index numbers of the text pairs that contain paraphrases. Then, list the index numbers of the text...
# 3725  Go over the 3 text pairs below. First, list the index numbers of the text pairs that contain paraphrases. Then, list the index numbers of the text...
# 4225  Go over the 3 text pairs below and list the index numbers of the text pairs where text A isn't a paraphrase of text B according to the following i...
# 4226  Go over the 3 text pairs below and list the index numbers of the text pairs where text A is a paraphrase of text B according to the following inst...
#
#                           answer targetLabel  \
# 0                            Yes          NA
# 1725              [No, Yes, Yes]          NA
# 2225                         [1]          No
# 2226                      [2, 3]         Yes
# 3225  {'no': [1], 'yes': [2, 3]}          NA
# 3725  {'no': [1], 'yes': [2, 3]}          NA
# 4225                         {1}          No
# 4226                      {2, 3}         Yes
#
#                                           task  #shot    CoT  taskSize  \
# 0                                   single_clf      0  False         1
# 1725                                 batch_clf      0  False         3
# 2225            index_selection_one_cat_a_time      0  False         3
# 2226            index_selection_one_cat_a_time      0  False         3
# 3225           index_selection_all_cat_at_once      0  False         3
# 3725  index_selection_all_cat_at_once_adjusted      0  False         3
# 4225       index_selection_one_cat_a_time_json      0  False         3
# 4226       index_selection_one_cat_a_time_json      0  False         3
#
#             gpt-3.5-turbo-0125-completion  \
# 0                                     Yes
# 1725                 1. No\n2. No\n3. Yes
# 2225                                None.
# 2226               1. None\n2. None\n3. 3
# 3225  {\n  "yes": [1],\n  "no": [2, 3]\n}
# 3725                                 None
# 4225                                  NaN
# 4226                                  NaN
#
#                                                                                                                   meta-llama/Llama-3-70b-chat-hf-completion  \
# 0                                                                                                                                                       Yes
# 1725  Here are the comparisons:\n\n**Pair 1:**\n\n* Text A: China's Health Ministry said five more people had died of Sars and a further 159 were infect...
# 2225                                                                                                                                                      1
# 2226                                                                                                                                                   2\n3
# 3225  Here is the output:\n\n{'yes': [1, 2, 3], 'no': []}\n\nExplanation:\n\n* Text pair 1 contains paraphrases, as both texts report on the same topic ...
# 3725                                                                                                                                                   None
# 4225                                                                                                                                                    NaN
# 4226                                                                                                                                                    NaN
#
#                                                                                                             mistralai/Mixtral-8x7B-Instruct-v0.1-completion  \
# 0      Yes, text A is a paraphrase of text B. Both texts convey the same information, stating that Mike Butcher, the Chief Operating Officer, and Alex A...
# 1725   1. Text A: China's Health Ministry said five more people had died of Sars and a further 159 were infected.\n   Text B: On Monday, China said nine...
# 2225   The answers for each text pair:\n\n1. The texts are not exact paraphrases, but they convey the same information and use a similar structure. Text...
# 2226                                                                                                                                                     1.
# 3225                                                                                                                    {\n  'yes': [1, 3],\n  'no': [2]\n}
# 3725                                                                                                                                                   None
# 4225                                                                                                                                                    NaN
# 4226                                                                                                                                                    NaN
#
#                                                                                                                    meta-llama/Llama-3-8b-chat-hf-completion  \
# 0                                                                                                                                                       Yes
# 1725  Here are the comparisons:\n\n1. Text A: China's Health Ministry said five more people had died of Sars and a further 159 were infected.\nText B: O...
# 2225  After analyzing the text pairs, I found that:\n\n* Text A and Text B in pair 1 are paraphrases of each other, as they both report the same informa...
# 2226  After analyzing the text pairs, I found that:\n\n* Text A in pair 1 is not a paraphrase of Text B, as the numbers of deaths and infections are dif...
# 3225  Here is the output in JSON format:\n\n{\n"yes": [1, 3],\n"no": [2]\n}\n\nExplanation:\n\n* Text pair 1 contains paraphrases, as both texts report ...
# 3725                                                                                                                                                   None
# 4225                                                                                                                                                    NaN
# 4226                                                                                                                                                    NaN
#
#         gpt-4-turbo-2024-04-09-completion  lmsys/vicuna-13b-v1.5-completion  \
# 0                                     Yes                              Yes.
# 1725                1. No\n2. Yes\n3. Yes             1. No\n2. Yes\n3. Yes
# 2225                                    1                             None.
# 2226                                    3                             None.
# 3225  {\n  "yes": [3],\n  "no": [1, 2]\n}   {\n"yes": [1, 3],\n"no": [2]\n}
# 3725                                 None                              None
# 4225                                  NaN                               NaN
# 4226                                  NaN                               NaN
#
#                                                                                                               mistralai/Mistral-7B-Instruct-v0.2-completion
# 0      Yes, text A is a paraphrase of text B. Both texts convey the same meaning, which is that Mike Butcher and Alex Arena report directly to So. The o...
# 1725   1. Yes, both texts report an increase in deaths and infections from SARS, with slight differences in wording.\n2. Yes, both texts report Intel's ...
# 2225   None.\n\nIn all three text pairs, text A can be considered a paraphrase of text B, as both texts convey the same essential information using diff...
# 2226   None.\n\nWhile the text pairs share similarities, they are not exact paraphrases of each other. The differences in word choice, sentence structur...
# 3225   {'yes': [1], 'no': [2, 3]}\n\nExplanation:\nText pair 1 contains paraphrases as both texts report the number of deaths and new infections from SA...
# 3725                                                                                                                                                   None
# 4225                                                                                                                                                    NaN
# 4226                                                                                                                                                    NaN

# %%
# out["lmsys/vicuna-13b-v1.5-completion"].str.contains("TOO_").sum()
# Out:
# 0
